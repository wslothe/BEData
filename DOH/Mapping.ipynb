# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
from IPython.display import display
# %matplotlib inline
plt.rcParams['figure.figsize'] = [30, 20]

# %%
zipshapes = gpd.read_file("zipshapes")

# %%
print(zipshapes['ZCTA5CE10'])
# Out:
# 0       17301
# 1       17353
# 2       17325
# 3       15018
# 4       15215
#         ...
# 1793    17329
# 1794    17363
# 1795    17318
# 1796    17361
# 1797    17355
# Name: ZCTA5CE10, Length: 1798, dtype: object

# %%
zipshapes = zipshapes.sort_values(by='ZCTA5CE10')

# %%
zipshapes = gpd.read_file("zipshapes.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda\lib\encodings\cp1252.py in decode(self, input, errors)
#      14     def decode(self,input,errors='strict'):
# ---> 15         return codecs.charmap_decode(input,errors,decoding_table)
#      16
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-409-fc57f68fe058> in <module>
# ----> 1 zipshapes = gpd.read_file("zipshapes.csv")
#
# ~\Anaconda\lib\site-packages\geopandas\io\file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     201                 )
#     202
# --> 203             return GeoDataFrame.from_features(
#     204                 f_filt, crs=crs, columns=columns + ["geometry"]
#     205             )
#
# ...

# %%
zipshapes = zipshapes.iloc[498:533, :]

# %%
zipshapes.to_file(driver='ESRI Shapefile', filename = 'zipshapes')

# %%
zipshapes
# Out:
#    STATEFP10  ZCTA5CE10  GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10    ALAND10  \
# 0         42      16001  4216001        B5   G6350          S  190155984
# 1         42      16002  4216002        B5   G6350          S  187002976
# 2         42      16020  4216020        B5   G6350          S   66025419
# 3         42      16022  4216022        B5   G6350          S    2079662
# 4         42      16023  4216023        B5   G6350          S   68120212
# 5         42      16024  4216024        B5   G6350          S     611593
# 6         42      16025  4216025        B5   G6350          S  137814359
# 7         42      16027  4216027        B5   G6350          S    1373158
# 8         42      16028  4216028        B5   G6350          S   41291276
# 9         42      16029  4216029        B5   G6350          S    2241392
# 10        42      16030  4216030        B5   G6350          S    2806303
# 11        42      16033  4216033        B5   G6350          S   80026877
# ...

# %%
df.plot(column = 'Cumulative Incidence', legend = True)
# Out:
# <AxesSubplot:>

# %%
df = gpd.GeoDataFrame(pd.concat([zipshapes2, munishapes, data2], axis=1))
#df = df.concat(zipshapes2, axis = 1)
#df = df.concat(munishapes, axis = 1)
#df = df.concat(data2, axis = 1)

# %%
zipshapes2.plot(column = data2['Fully Covered Rate'], legend = True)
# Out:
# <AxesSubplot:>

# %%
data = pd.read_csv("20210813_zip_code_data.csv")

# %%
shared = list(set(data['postcode']).intersection(zipshapes['ZCTA5CE10']))

# %%
zipshapes['ZCTA5CE10'] = zipshapes['ZCTA5CE10'].astype('int')

# %%
data['postcode'] = data['postcode'].astype('int')

# %%
data2 = data[data['postcode'].isin(shared)]

# %%
zipshapes2 = zipshapes[zipshapes['ZCTA5CE10'].isin(shared)]

# %%
data2 = data2.reset_index(drop = True)
data2
# Out:
#     postcode  Positive  Negative  Cumulative Incidence  Partially Covered  \
# 0      16001      2159     11703               5557.70             1288.0
# 1      16002       800      3847               5243.49              455.0
# 2      16020        58       260               5030.36               38.0
# 3      16022        27        96               6994.82               10.0
# 4      16023       573      1387              12847.53              211.0
# 5      16024        23        79               9913.79               12.0
# 6      16025       358      1287               6892.57              144.0
# 7      16027        12       103               4687.50               20.0
# 8      16028       122       438               7554.18               48.0
# 9      16029        36       178               4851.75               21.0
# 10     16030        15        60               5050.51                6.0
# 11     16033       345      1714               5511.18              232.0
# ...

# %%
zipshapes2.bounds.iloc[0]
# Out:
# minx   -80.037518
# miny    40.816301
# maxx   -79.813133
# maxy    41.007205
# Name: 1635, dtype: float64

# %%
zipshapes = zipshapes.reset_index(drop = True)

# %%
zipshapes2 = zipshapes2.reset_index(drop = True)

# %%
zipshapes2
# Out:
#    STATEFP10  ZCTA5CE10  GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10    ALAND10  \
# 0         42      16001  4216001        B5   G6350          S  190155984
# 1         42      16002  4216002        B5   G6350          S  187002976
# 2         42      16020  4216020        B5   G6350          S   66025419
# 3         42      16022  4216022        B5   G6350          S    2079662
# 4         42      16023  4216023        B5   G6350          S   68120212
# 5         42      16024  4216024        B5   G6350          S     611593
# 6         42      16025  4216025        B5   G6350          S  137814359
# 7         42      16027  4216027        B5   G6350          S    1373158
# 8         42      16028  4216028        B5   G6350          S   41291276
# 9         42      16029  4216029        B5   G6350          S    2241392
# 10        42      16030  4216030        B5   G6350          S    2806303
# 11        42      16033  4216033        B5   G6350          S   80026877
# ...

# %%
df
# Out:
#    STATEFP10  ZCTA5CE10  GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10      ALAND10  \
# 0         42    16001.0  4216001        B5   G6350          S  190155984.0
# 1         42    16002.0  4216002        B5   G6350          S  187002976.0
# 2         42    16020.0  4216020        B5   G6350          S   66025419.0
# 3         42    16022.0  4216022        B5   G6350          S    2079662.0
# 4         42    16023.0  4216023        B5   G6350          S   68120212.0
# ..       ...        ...      ...       ...     ...        ...          ...
# 30       NaN        NaN      NaN       NaN     NaN        NaN          NaN
# 31       NaN        NaN      NaN       NaN     NaN        NaN          NaN
# 32       NaN        NaN      NaN       NaN     NaN        NaN          NaN
# 33       NaN        NaN      NaN       NaN     NaN        NaN          NaN
# 34       NaN        NaN      NaN       NaN     NaN        NaN          NaN
#
# ...
